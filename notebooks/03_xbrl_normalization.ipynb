# %% [markdown]
# # XBRL Normalization

# %%
import duckdb
duckdb.connect("data/processed/filingsgraph.duckdb").sql("select normalized_metric,count(*) n from facts group by 1 order by n desc limit 20").df()
